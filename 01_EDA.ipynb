# %% [markdown]
# # EDA (Exploratory Data Analysis) for all Data Roles

# %% [markdown]
# ## Roles to Explore

# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# Loading Dataset
df = pd.read_csv(r'C:\Users\ARJUN\Python_projects\Python_Course\data_jobs.csv')

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)

# %%
# df_plot.plot(kind = 'barh', y = 'job_cnt')
# plt.gca().invert_yaxis()

df_plot = df['job_title_short'].value_counts().to_frame(name = 'job_cnt')

sns.set_theme(style = 'ticks')
sns.barplot(data = df_plot, x = 'job_cnt', y = df_plot.index, hue = 'job_cnt', palette = 'dark:b_r')
sns.despine()
plt.title('Number of Jobs per Title')
plt.xlabel('')
plt.ylabel('')
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x/1000)}K'))
plt.legend().set_visible(False)
plt.show()

# %% [markdown]
# ## Countries to Explore

# %%
# df_plot.plot(kind = 'barh', y = 'job_cnt')
# plt.gca().invert_yaxis()

df_plot = df['job_country'].value_counts().head(20).to_frame(name = 'job_cnt')

sns.set_theme(style = 'ticks')
sns.barplot(data = df_plot, x = 'job_cnt', y = df_plot.index, hue = 'job_cnt', palette = 'dark:b_r')
sns.despine()
plt.title('Number of Jobs per Country')
plt.xlabel('')
plt.ylabel('')
plt.legend().remove()
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x/1000)}K'))
plt.show()

# %% [markdown]
# ## Companies to Explore

# %%
# df_plot.plot(kind = 'barh', y = 'job_cnt')
# plt.gca().invert_yaxis()

df_plot = df['company_name'].value_counts().head(20)[1:].to_frame(name = 'job_cnt')

sns.set_theme(style = 'ticks')
sns.barplot(data = df_plot, x = 'job_cnt', y = df_plot.index, hue = 'job_cnt', palette = 'dark:b_r')
sns.despine()
plt.title('Number of Jobs per Company')
plt.xlabel('')
plt.ylabel('')
plt.legend().remove()
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.show()

# %% [markdown]
# ## Perks of Data Jobs

# %%
fig, ax = plt.subplots(1,3)
fig.set_size_inches(12,5)

dict_column = ({
    'job_work_from_home':'Work from Home Offered', 
    'job_no_degree_mention':'Degree Required', 
    'job_health_insurance':'Health Insurance Offered'
})

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df[column].value_counts(), startangle = 90, autopct = '%1.1f%%', labels = ['False','True'])
    ax[i].set_title(title)

plt.suptitle('Perks of Data Jobs')
fig.tight_layout()
plt.show()

# %% [markdown]
# # EDA (Exploratory Data Analysis) for all Data Analysts in the US

# %%
# Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ast

# Loading Dataset
df = pd.read_csv(r'C:\Users\ARJUN\Python_projects\Python_Course\data_jobs.csv')

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda skill_list: ast.literal_eval(skill_list) if pd.notna(skill_list) else skill_list)

# %% [markdown]
# # Filter for US Data Analysts

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') &  (df['job_country'] == 'United States')].copy()

# %% [markdown]
# ## Locations to Explore

# %%
# df_plot.plot(kind = 'barh', y = 'count')
# plt.gca().invert_yaxis()

df_plot = df_DA_US['job_location'].value_counts().head(10).to_frame(name = 'location_count')

sns.set_theme(style = 'ticks')
sns.barplot(data = df_plot, x = 'location_count', y = df_plot.index, hue = 'location_count', palette = 'dark:b_r')
sns.despine()
plt.title('Number of Jobs per Location for Data Analysts in the US')
plt.xlabel('')
plt.ylabel('')
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x/1000)}K'))
plt.legend().set_visible(False)
plt.show()

# %% [markdown]
# ## Perks of Data Jobs

# %%
fig, ax = plt.subplots(1,3)
fig.set_size_inches(12,5)

dict_column = ({
    'job_work_from_home':'Work from Home Offered', 
    'job_no_degree_mention':'Degree Required', 
    'job_health_insurance':'Health Insurance Offered'
})

for i, (column, title) in enumerate(dict_column.items()):
    ax[i].pie(df_DA_US[column].value_counts(), startangle = 90, autopct = '%1.1f%%', labels = ['False','True'])
    ax[i].set_title(title)

plt.suptitle('Perks of Data Jobs')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Companies to Explore

# %%
# df_plot.plot(kind = 'barh', y = 'job_cnt')
# plt.gca().invert_yaxis()

df_plot = df_DA_US['company_name'].value_counts().head(10).to_frame(name = 'job_cnt')

sns.set_theme(style = 'ticks')
sns.barplot(data = df_plot, x = 'job_cnt', y = df_plot.index, hue = 'job_cnt', palette = 'dark:b_r')
sns.despine()
plt.title('Number of Jobs per Company for Data Analysts in the US')
plt.xlabel('')
plt.ylabel('')
plt.legend().remove()
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{int(x):,}'))
plt.show()
